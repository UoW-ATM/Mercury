# %%
# %pylab inline

import sys
sys.path.insert(1,'..')

from Mercury import Mercury, ParametriserSelector, ResultsAggregatorSelector, read_scenario_config, read_mercury_config

from Mercury.libs.uow_tool_belt.general_tools import clock_time
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# /home/earendil/Documents/Westminster/Mercury/Mercury/../Mercury/libs/db_access_functions.py:361: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   d_curfew['curfew'] = d_curfew['curfew'].apply(lambda x: (dt.datetime.min + x).time() if not x is -1 else None)

# %% [markdown]
# # Simplest use

# %%
# Choose scenario to simulate
scenarios = [-1]

# Initialise simulation
mercury = Mercury()

# Run and get results
with clock_time():
    results, results_seq = mercury.run(scenarios=scenarios)
# Out:
# Simulating scenario: -1
# Simulating case study: 0
# Building world...
# Starting loading data at 2023-11-28 00:41:16.999471
# Memory of process: 245 MB
# Getting BADA performances... executed in 0:00:00.616712
# Getting schedules... executed in 0:00:00.011053
# Getting ATFM probabilities... executed in 0:00:00.008890
# Getting days regulations at airports... executed in 0:00:00.001257
# Getting flight plan pool... executed in 0:00:00.613752
# Creating flight plans... executed in 0:00:10.024857
# Getting/Creating flight plans... executed in 0:00:10.638960
# Getting curfews... executed in 0:00:00.012504
# Getting airports data... executed in 0:00:00.016670
# Getting EAMAN data... executed in 0:00:00.001777
# Getting cost data... executed in 0:00:00.038576
# Getting airline data... executed in 0:00:00.002679
# Getting flight uncertainty data... executed in 0:00:00.006138
# Getting soft cost data... executed in 0:00:00.002814
# Getting pax data... executed in 0:00:00.024003
# Getting ATFM data... executed in 0:00:00.011589
# Number of flights that can propagate to curfew: 0
# Computing flights can propagate curfew... executed in 0:00:00.008743
# Memory of process: 543 MB
# Modules to be loaded: []
# Building agents...
# Running simulation...
# executed in 0:02:14.615544

# %%
results
# Out:
#                                  arrival_delay_min             fuel_cost_m3  \
#                                               mean        std          mean
# scenario_id case_study_id n_iter
# -2          0             0              -0.157246  26.487671  19420.719675
#
#                                               departure_delay_min             \
#                                           std                mean        std
# scenario_id case_study_id n_iter
# -2          0             0       15517.29392           13.310132  13.598672
#
#                                  cancelled              total_cost  \
#                                       mean       std          mean
# scenario_id case_study_id n_iter
# -2          0             0       0.016983  0.129272  21774.547173
#
#                                                 ...  \
#                                            std  ...
# scenario_id case_study_id n_iter                ...
# -2          0             0       16339.117742  ...
#
#                                  reg_eaman_diff_tact_planned_delay_assigned  \
#                                                                        mean
# scenario_id case_study_id n_iter
# -2          0             0                                             0.0
#
#                                      pax_tot_arrival_delay               \
#                                  std                  mean          std
# scenario_id case_study_id n_iter
# -2          0             0      NaN            189.942564  1370.243715
#
#                                  pax_modified_itinerary           \
#                                                    mean      std
# scenario_id case_study_id n_iter
# -2          0             0                    0.019129  0.13698
#
#                                  pax_p2p_tot_arrival_delay               \
#                                                       mean          std
# scenario_id case_study_id n_iter
# -2          0             0                     189.942564  1370.243715
#
#                                  pax_p2p_modified_itinerary
#                                                        mean      std
# scenario_id case_study_id n_iter
# -2          0             0                        0.019129  0.13698
#
# [1 rows x 106 columns]

# %% [markdown]
# # Iterate through scenarios

# %%
# # Choose scenario to simulate
# scenarios = [-4, -5]

# # Initialise simulation
# mercury = Mercury()

# # Run and get results
# with clock_time():
#     results, results_seq = mercury.run(scenarios=scenarios)
# Out:
# Simulating scenario: -4
# Building world...
# Starting loading data at 2023-11-24 18:53:22.764301
# Memory of process: 315 MB
# Getting BADA performances... executed in 0:00:00.964937
# Getting schedules... executed in 0:00:00.019357
# Getting ATFM probabilities... executed in 0:00:00.008979
# Getting days regulations at airports... executed in 0:00:00.001302
# Getting flight plan pool... executed in 0:00:00.257956
# Creating flight plans... executed in 0:00:00.022531
# Getting/Creating flight plans... executed in 0:00:00.280644
# Getting curfews... executed in 0:00:00.008545
# Getting airports data... executed in 0:00:00.012472
# Getting EAMAN data... executed in 0:00:00.001734
# Getting cost data... executed in 0:00:00.035687
# Getting airline data... executed in 0:00:00.001844
# Getting flight uncertainty data... executed in 0:00:00.005968
# Getting soft cost data... executed in 0:00:00.002808
# Getting pax data... executed in 0:00:00.036158
# Getting ATFM data... executed in 0:00:00.010166
# Number of flights that can propagate to curfew: 1
# Computing flights can propagate curfew... executed in 0:00:00.006885
# Memory of process: 331 MB
# Modules to be loaded: []
# Building agents...
# Running simulation...
# Simulating scenario: -5
# Building world...
# Starting loading data at 2023-11-24 18:53:25.366592
# Memory of process: 335 MB
# Getting BADA performances... executed in 0:00:00.919600
# Getting schedules... executed in 0:00:00.023669
# Getting ATFM probabilities... executed in 0:00:00.010666
# Getting days regulations at airports... executed in 0:00:00.001650
# Getting flight plan pool... executed in 0:00:00.303190
# Creating flight plans... executed in 0:00:00.019893
# Getting/Creating flight plans... executed in 0:00:00.323235
# Getting curfews... executed in 0:00:00.010208
# Getting airports data... executed in 0:00:00.016522
# Getting EAMAN data... executed in 0:00:00.001868
# Getting cost data... executed in 0:00:00.038248
# Getting airline data... executed in 0:00:00.002527
# Getting flight uncertainty data... executed in 0:00:00.006324
# Getting soft cost data... executed in 0:00:00.003079
# Getting pax data... executed in 0:00:00.040231
# Getting ATFM data... executed in 0:00:00.011020
# Number of flights that can propagate to curfew: 1
# Computing flights can propagate curfew... executed in 0:00:00.006759
# Memory of process: 375 MB
# Modules to be loaded: []
# Building agents...
# Running simulation...
# executed in 0:00:05.227893

# %%
# results
# Out:
#                                  arrival_delay_min            fuel_cost_m3  \
#                                               mean        std         mean
# scenario_id case_study_id n_iter
# -5          0             0                 -3.720  10.975163     1854.352
# -4          0             0                  0.926  12.210300     1931.668
#
#                                              departure_delay_min             \
#                                          std                mean        std
# scenario_id case_study_id n_iter
# -5          0             0       320.827006                7.29  10.837943
# -4          0             0       320.394613                8.94  11.876043
#
#                                  cancelled      total_cost              ...  \
#                                       mean  std       mean         std  ...
# scenario_id case_study_id n_iter                                        ...
# -5          0             0            0.0  0.0   2867.380  449.040078  ...
# -4          0             0            0.0  0.0   2990.116  463.017978  ...
#
#                                  reg_eaman_diff_tact_planned_delay_assigned  \
#                                                                        mean
# scenario_id case_study_id n_iter
# -5          0             0                                             NaN
# -4          0             0                                             NaN
#
#                                      pax_tot_arrival_delay             \
#                                  std                  mean        std
# scenario_id case_study_id n_iter
# -5          0             0      NaN             -3.170041  10.005447
# -4          0             0      NaN             -0.848416   8.978572
#
#                                  pax_modified_itinerary       \
#                                                    mean  std
# scenario_id case_study_id n_iter
# -5          0             0                         0.0  0.0
# -4          0             0                         0.0  0.0
#
#                                  pax_p2p_tot_arrival_delay             \
#                                                       mean        std
# scenario_id case_study_id n_iter
# -5          0             0                      -3.170041  10.005447
# -4          0             0                      -0.848416   8.978572
#
#                                  pax_p2p_modified_itinerary
#                                                        mean  std
# scenario_id case_study_id n_iter
# -5          0             0                             0.0  0.0
# -4          0             0                             0.0  0.0
#
# [2 rows x 90 columns]

# %% [markdown]
# # Iterate through case studies

# %%
# Choose scenario to simulate
scenarios = [-1]

# Choose case studies to simulate
case_studies = [0, -1]

# Initialise simulation
mercury = Mercury()

# Run and get results
with clock_time():
    results, results_seq = mercury.run(scenarios=scenarios,
                                      case_studies=case_studies)
# Out:
# Simulating scenario: -1
# Simulating case study: 0
# Building world...
# Starting loading data at 2023-11-28 01:15:02.520971
# Memory of process: 1328 MB
# Getting BADA performances... executed in 0:00:01.000578
# Getting schedules... executed in 0:00:00.031612
# Getting ATFM probabilities... executed in 0:00:00.028155
# Getting days regulations at airports... executed in 0:00:00.003125
# Getting flight plan pool... executed in 0:00:00.661742
# Creating flight plans... executed in 0:00:21.596177
# Getting/Creating flight plans... executed in 0:00:22.258503
# Getting curfews... executed in 0:00:00.023125
# Getting airports data... executed in 0:00:00.034624
# Getting EAMAN data... executed in 0:00:00.003541
# Getting cost data... executed in 0:00:00.063893
# Getting airline data... executed in 0:00:00.006356
# Getting flight uncertainty data... executed in 0:00:00.011892
# Getting soft cost data... executed in 0:00:00.005510
# Getting pax data... executed in 0:00:00.077658
# Getting ATFM data... executed in 0:00:00.024984
# Number of flights that can propagate to curfew: 0
# Computing flights can propagate curfew... executed in 0:00:00.016698
# Memory of process: 1400 MB
# Modules to be loaded: []
# Building agents...
# Running simulation...
# Simulating case study: -1
# Building world...
# Starting loading data at 2023-11-28 01:18:17.610944
# Memory of process: 1770 MB
# Getting BADA performances... executed in 0:00:00.611304
# Getting schedules... executed in 0:00:00.010332
# Getting ATFM probabilities... executed in 0:00:00.009407
# Getting days regulations at airports... executed in 0:00:00.001257
# Getting flight plan pool... executed in 0:00:00.139386
# Creating flight plans... executed in 0:00:00.307177
# Getting/Creating flight plans... executed in 0:00:00.446788
# Getting curfews... executed in 0:00:00.009341
# Getting airports data... executed in 0:00:00.011915
# Getting EAMAN data... executed in 0:00:00.001652
# Getting cost data... executed in 0:00:00.035959
# Getting airline data... executed in 0:00:00.002273
# Getting flight uncertainty data... executed in 0:00:00.006092
# Getting soft cost data... executed in 0:00:00.002890
# Getting pax data... executed in 0:00:00.006413
# Getting ATFM data... executed in 0:00:00.011008
# Number of flights that can propagate to curfew: 0
# Computing flights can propagate curfew... executed in 0:00:00.004880
# Memory of process: 1780 MB
# Modules to be loaded: []
# Building agents...
# Running simulation...
# executed in 0:03:24.543421

# %%
results
# Out:
#                                  arrival_delay_min             fuel_cost_m3  \
#                                               mean        std          mean
# scenario_id case_study_id n_iter
# -1          -1            0             -10.716176  18.526047  21249.715588
#              0            0              -0.306259  26.499569  19449.050469
#
#                                                departure_delay_min             \
#                                            std                mean        std
# scenario_id case_study_id n_iter
# -1          -1            0       19283.746470            9.209412   8.731280
#              0            0       15385.057389           12.995372  14.018528
#
#                                  cancelled              total_cost  \
#                                       mean       std          mean
# scenario_id case_study_id n_iter
# -1          -1            0        0.00000  0.000000  23803.491471
#              0            0        0.01998  0.140001  21756.363067
#
#                                                 ...  \
#                                            std  ...
# scenario_id case_study_id n_iter                ...
# -1          -1            0       20065.216179  ...
#              0            0       16210.068981  ...
#
#                                  reg_eaman_diff_tact_planned_delay_assigned  \
#                                                                        mean
# scenario_id case_study_id n_iter
# -1          -1            0                                             NaN
#              0            0                                             0.0
#
#                                      pax_tot_arrival_delay               \
#                                  std                  mean          std
# scenario_id case_study_id n_iter
# -1          -1            0      NaN            -12.395115    17.159658
#              0            0      NaN            219.598743  1472.354466
#
#                                  pax_modified_itinerary            \
#                                                    mean       std
# scenario_id case_study_id n_iter
# -1          -1            0                    0.000000  0.000000
#              0            0                    0.022153  0.147182
#
#                                  pax_p2p_tot_arrival_delay               \
#                                                       mean          std
# scenario_id case_study_id n_iter
# -1          -1            0                     -12.395115    17.159658
#              0            0                     219.598743  1472.354466
#
#                                  pax_p2p_modified_itinerary
#                                                        mean       std
# scenario_id case_study_id n_iter
# -1          -1            0                        0.000000  0.000000
#              0            0                        0.022153  0.147182
#
# [2 rows x 106 columns]

# %% [markdown]
# You can also iterate through scenarios and case studies, if all case studies are defined in all scenarios.

# %%
# # Choose scenario to simulate

# scenarios = [-4, -5]

# # Choose case studies to simulate
# case_studies = [0, -1]

# # Initialise simulation
# mercury = Mercury()

# # Run and get results
# with clock_time():
#     results, results_seq = mercury.run(scenarios=scenarios,
#                                       case_studies=case_studies)
# Out:
# Simulating scenario: -4
# Simulating case study: 0
# Building world...
# Starting loading data at 2023-11-24 19:00:25.120537
# Memory of process: 210 MB
# Getting BADA performances... executed in 0:00:01.055506
# Getting schedules... executed in 0:00:00.024865
# Getting ATFM probabilities... executed in 0:00:00.011768
# Getting days regulations at airports... executed in 0:00:00.001427
# Getting flight plan pool... executed in 0:00:00.236286
# Creating flight plans... executed in 0:00:00.024484
# Getting/Creating flight plans... executed in 0:00:00.260937
# Getting curfews... executed in 0:00:00.009546
# Getting airports data... executed in 0:00:00.012745
# Getting EAMAN data... executed in 0:00:00.001639
# Getting cost data... executed in 0:00:00.037549
# Getting airline data... executed in 0:00:00.002166
# Getting flight uncertainty data... executed in 0:00:00.006760
# Getting soft cost data... executed in 0:00:00.003052
# Getting pax data... executed in 0:00:00.035490
# Getting ATFM data... executed in 0:00:00.010993
# Number of flights that can propagate to curfew: 1
# Computing flights can propagate curfew... executed in 0:00:00.007068
# Memory of process: 307 MB
# Modules to be loaded: []
# Building agents...
# Running simulation...
# Simulating case study: -1
# Building world...
# Starting loading data at 2023-11-24 19:00:27.877548
# Memory of process: 316 MB
# Getting BADA performances... executed in 0:00:01.015223
# Getting schedules... executed in 0:00:00.028178
# Getting ATFM probabilities... executed in 0:00:00.011407
# Getting days regulations at airports... executed in 0:00:00.002038
# Getting flight plan pool... executed in 0:00:00.316703
# Creating flight plans... executed in 0:00:00.023957
# Getting/Creating flight plans... executed in 0:00:00.340872
# Getting curfews... executed in 0:00:00.011037
# Getting airports data... executed in 0:00:00.018873
# Getting EAMAN data... executed in 0:00:00.001818
# Getting cost data... executed in 0:00:00.045741
# Getting airline data... executed in 0:00:00.003580
# Getting flight uncertainty data... executed in 0:00:00.011156
# Getting soft cost data... executed in 0:00:00.003764
# Getting pax data... executed in 0:00:00.041636
# Getting ATFM data... executed in 0:00:00.009810
# Number of flights that can propagate to curfew: 1
# Computing flights can propagate curfew... executed in 0:00:00.007030
# Memory of process: 359 MB
# Modules to be loaded: []
# Building agents...
# Running simulation...
# Simulating scenario: -5
# Simulating case study: 0
# Building world...
# Starting loading data at 2023-11-24 19:00:30.737326
# Memory of process: 359 MB
# Getting BADA performances... executed in 0:00:00.980629
# Getting schedules... executed in 0:00:00.022967
# Getting ATFM probabilities... executed in 0:00:00.009557
# Getting days regulations at airports... executed in 0:00:00.002078
# Getting flight plan pool... executed in 0:00:00.286927
# Creating flight plans... executed in 0:00:00.021221
# Getting/Creating flight plans... executed in 0:00:00.308316
# Getting curfews... executed in 0:00:00.009249
# Getting airports data... executed in 0:00:00.012597
# Getting EAMAN data... executed in 0:00:00.001613
# Getting cost data... executed in 0:00:00.038018
# Getting airline data... executed in 0:00:00.001890
# Getting flight uncertainty data... executed in 0:00:00.007147
# Getting soft cost data... executed in 0:00:00.002928
# Getting pax data... executed in 0:00:00.035586
# Getting ATFM data... executed in 0:00:00.010572
# Number of flights that can propagate to curfew: 1
# Computing flights can propagate curfew... executed in 0:00:00.006747
# Memory of process: 394 MB
# Modules to be loaded: []
# Building agents...
# Running simulation...
# Simulating case study: -1
# Building world...
# Starting loading data at 2023-11-24 19:00:33.449206
# Memory of process: 394 MB
# Getting BADA performances... executed in 0:00:01.193639
# Getting schedules... executed in 0:00:00.025372
# Getting ATFM probabilities... executed in 0:00:00.011429
# Getting days regulations at airports... executed in 0:00:00.001375
# Getting flight plan pool... executed in 0:00:00.244582
# Creating flight plans... executed in 0:00:00.019709
# Getting/Creating flight plans... executed in 0:00:00.264465
# Getting curfews... executed in 0:00:00.008888
# Getting airports data... executed in 0:00:00.014224
# Getting EAMAN data... executed in 0:00:00.001634
# Getting cost data... executed in 0:00:00.036491
# Getting airline data... executed in 0:00:00.001901
# Getting flight uncertainty data... executed in 0:00:00.006348
# Getting soft cost data... executed in 0:00:00.002830
# Getting pax data... executed in 0:00:00.038455
# Getting ATFM data... executed in 0:00:00.010576
# Number of flights that can propagate to curfew: 1
# Computing flights can propagate curfew... executed in 0:00:00.007472
# Memory of process: 396 MB
# Modules to be loaded: []
# Building agents...
# Running simulation...
# executed in 0:00:11.214559

# %%
# results
# Out:
#                                  arrival_delay_min            fuel_cost_m3  \
#                                               mean        std         mean
# scenario_id case_study_id n_iter
# -5          -1            0               -13.7875   6.657329     1786.915
#              0            0                -2.4520  18.584327     1819.958
# -4          -1            0                -7.5080  10.914581     1724.562
#              0            0                16.4700  21.633291     1800.578
#
#                                              departure_delay_min             \
#                                          std                mean        std
# scenario_id case_study_id n_iter
# -5          -1            0       342.781399               5.390   4.727149
#              0            0       232.454904               8.852   7.963659
# -4          -1            0       379.043679               2.622   2.900840
#              0            0       337.704767              16.206  14.586389
#
#                                  cancelled           total_cost              \
#                                       mean       std       mean         std
# scenario_id case_study_id n_iter
# -5          -1            0            0.2  0.447214   3043.142  714.972936
#              0            0            0.0  0.000000   2848.446  427.914072
# -4          -1            0            0.0  0.000000   2691.156  575.811609
#              0            0            0.0  0.000000   2904.014  571.491161
#
#                                   ...  \
#                                   ...
# scenario_id case_study_id n_iter  ...
# -5          -1            0       ...
#              0            0       ...
# -4          -1            0       ...
#              0            0       ...
#
#                                  reg_eaman_diff_tact_planned_delay_assigned  \
#                                                                        mean
# scenario_id case_study_id n_iter
# -5          -1            0                                             NaN
#              0            0                                             NaN
# -4          -1            0                                             NaN
#              0            0                                             NaN
#
#                                      pax_tot_arrival_delay               \
#                                  std                  mean          std
# scenario_id case_study_id n_iter
# -5          -1            0      NaN           2316.185479  4230.928715
#              0            0      NaN             -1.061711    18.327867
# -4          -1            0      NaN             -6.869992    10.771605
#              0            0      NaN             13.522065    17.353748
#
#                                  pax_modified_itinerary            \
#                                                    mean       std
# scenario_id case_study_id n_iter
# -5          -1            0                    0.232653  0.422523
#              0            0                    0.000000  0.000000
# -4          -1            0                    0.000000  0.000000
#              0            0                    0.000000  0.000000
#
#                                  pax_p2p_tot_arrival_delay               \
#                                                       mean          std
# scenario_id case_study_id n_iter
# -5          -1            0                    2316.185479  4230.928715
#              0            0                      -1.061711    18.327867
# -4          -1            0                      -6.869992    10.771605
#              0            0                      13.522065    17.353748
#
#                                  pax_p2p_modified_itinerary
#                                                        mean       std
# scenario_id case_study_id n_iter
# -5          -1            0                        0.232653  0.422523
#              0            0                        0.000000  0.000000
# -4          -1            0                        0.000000  0.000000
#              0            0                        0.000000  0.000000
#
# [4 rows x 90 columns]

# %% [markdown]
# # Change and sweep parameters

# %%
# Change mercury config parameters
ps = read_mercury_config(config_file='config/mercury_config.toml')
ps['computation__num_iter'] = 2 # change parameters on the fly

# Choose scenario to be simulated
scenarios = [-1]


## Choose some values to be simulated

# The first dictionary will set values to a specific value for all iterations. If you want to sweep
# some parameters, see next dictionary
paras_sc_fixed = {
                'modules__modules_to_load':[]
                }

# The second dictionary will iterate through different values for each parameters. Each value of each parameter
# is simulated against all values of the other parameters.
paras_sc_iterated = {'airports__sig_ct':[15., 17.],
                       }
    
# All values that you do not specify in either of the dictionary will be set to their default value, defined in the scenario
# config file.

# %%
# Initialise simulation
mercury = Mercury()

# Run and get results
with clock_time():
    results, results_seq = mercury.run(scenarios=scenarios,
                                        paras_sc_iterated=paras_sc_iterated,
                                        paras_sc_fixed=paras_sc_fixed,
                                        paras_simulation=ps
                                      )
# Out:
# Simulating scenario: -1
# Simulating case study: 0
# airports__sig_ct = 15.0
# Building world...
# Starting loading data at 2023-11-28 01:18:27.121786
# Memory of process: 1781 MB
# Getting BADA performances... executed in 0:00:00.580771
# Getting schedules... executed in 0:00:00.011289
# Getting ATFM probabilities... executed in 0:00:00.008726
# Getting days regulations at airports... executed in 0:00:00.001247
# Getting flight plan pool... executed in 0:00:00.586535
# Creating flight plans... executed in 0:00:21.134471
# Getting/Creating flight plans... executed in 0:00:21.721444
# Getting curfews... executed in 0:00:00.034791
# Getting airports data... executed in 0:00:00.043015
# Getting EAMAN data... executed in 0:00:00.003833
# Getting cost data... executed in 0:00:00.076674
# Getting airline data... executed in 0:00:00.006971
# Getting flight uncertainty data... executed in 0:00:00.015239
# Getting soft cost data... executed in 0:00:00.006477
# Getting pax data... executed in 0:00:00.102726
# Getting ATFM data... executed in 0:00:00.024578
# Number of flights that can propagate to curfew: 0
# Computing flights can propagate curfew... executed in 0:00:00.026597
# Memory of process: 1918 MB
# Modules to be loaded: []
# Building agents...
# Running simulation...
# Resetting world...
# Deleting all agents and other objects (deep clean)
# Building agents...
# Running simulation...
# airports__sig_ct = 17.0
# Building world...
# Starting loading data at 2023-11-28 01:23:54.204284
# Memory of process: 2390 MB
# Getting BADA performances... executed in 0:00:00.591777
# Getting schedules... executed in 0:00:00.012439
# Getting ATFM probabilities... executed in 0:00:00.008977
# Getting days regulations at airports... executed in 0:00:00.001290
# Getting flight plan pool... executed in 0:00:00.464248
# Creating flight plans... executed in 0:00:14.320982
# Getting/Creating flight plans... executed in 0:00:14.785536
# Getting curfews... executed in 0:00:00.013884
# Getting airports data... executed in 0:00:00.018176
# Getting EAMAN data... executed in 0:00:00.002030
# Getting cost data... executed in 0:00:00.039561
# Getting airline data... executed in 0:00:00.002972
# Getting flight uncertainty data... executed in 0:00:00.006453
# Getting soft cost data... executed in 0:00:00.002921
# Getting pax data... executed in 0:00:00.030086
# Getting ATFM data... executed in 0:00:00.012285
# Number of flights that can propagate to curfew: 0
# Computing flights can propagate curfew... executed in 0:00:00.008853
# Memory of process: 2416 MB
# Modules to be loaded: []
# Building agents...
# Running simulation...
# Resetting world...
# Deleting all agents and other objects (deep clean)
# Building agents...
# Running simulation...
# executed in 0:10:51.378742

# %%
results
# Out:
#                                                   arrival_delay_min  \
#                                                                mean
# airports__sig_ct scenario_id case_study_id n_iter
# 15.0             -1          0             0               0.104074
#                                            1              -0.946049
# 17.0             -1          0             0               0.231273
#                                            1              -0.338118
#
#                                                               fuel_cost_m3  \
#                                                          std          mean
# airports__sig_ct scenario_id case_study_id n_iter
# 15.0             -1          0             0       26.857910  19387.730195
#                                            1       25.568459  19432.358854
# 17.0             -1          0             0       27.726504  19331.337454
#                                            1       25.752970  19412.937294
#
#                                                                  \
#                                                             std
# airports__sig_ct scenario_id case_study_id n_iter
# 15.0             -1          0             0       15349.438448
#                                            1       15415.266574
# 17.0             -1          0             0       15399.780683
#                                            1       15515.005080
#
#                                                   departure_delay_min  \
#                                                                  mean
# airports__sig_ct scenario_id case_study_id n_iter
# 15.0             -1          0             0                13.241420
#                                            1                12.541679
# 17.0             -1          0             0                13.458513
#                                            1                12.854466
#
#                                                              cancelled  \
#                                                          std      mean
# airports__sig_ct scenario_id case_study_id n_iter
# 15.0             -1          0             0       14.361408  0.028971
#                                            1       11.657350  0.023976
# 17.0             -1          0             0       15.665690  0.018981
#                                            1       12.513464  0.017982
#
#                                                                total_cost  \
#                                                         std          mean
# airports__sig_ct scenario_id case_study_id n_iter
# 15.0             -1          0             0       0.167809  21625.903646
#                                            1       0.153051  21684.506444
# 17.0             -1          0             0       0.136526  21662.928921
#                                            1       0.132952  21729.292048
#
#                                                                  ...  \
#                                                             std  ...
# airports__sig_ct scenario_id case_study_id n_iter                ...
# 15.0             -1          0             0       16146.456216  ...
#                                            1       16241.563640  ...
# 17.0             -1          0             0       16220.775734  ...
#                                            1       16346.039272  ...
#
#                                                   reg_eaman_diff_tact_planned_delay_assigned  \
#                                                                                         mean
# airports__sig_ct scenario_id case_study_id n_iter
# 15.0             -1          0             0                                             0.0
#                                            1                                             0.0
# 17.0             -1          0             0                                             0.0
#                                            1                                             0.0
#
#                                                       pax_tot_arrival_delay  \
#                                                   std                  mean
# airports__sig_ct scenario_id case_study_id n_iter
# 15.0             -1          0             0      NaN            303.078941
#                                            1      NaN            229.195214
# 17.0             -1          0             0      NaN            206.034415
#                                            1      NaN            171.720829
#
#                                                                 \
#                                                            std
# airports__sig_ct scenario_id case_study_id n_iter
# 15.0             -1          0             0       1718.757839
#                                            1       1504.757431
# 17.0             -1          0             0       1424.748360
#                                            1       1305.050083
#
#                                                   pax_modified_itinerary  \
#                                                                     mean
# airports__sig_ct scenario_id case_study_id n_iter
# 15.0             -1          0             0                    0.030452
#                                            1                    0.023161
# 17.0             -1          0             0                    0.020716
#                                            1                    0.017319
#
#                                                              \
#                                                         std
# airports__sig_ct scenario_id case_study_id n_iter
# 15.0             -1          0             0       0.171828
#                                            1       0.150416
# 17.0             -1          0             0       0.142431
#                                            1       0.130459
#
#                                                   pax_p2p_tot_arrival_delay  \
#                                                                        mean
# airports__sig_ct scenario_id case_study_id n_iter
# 15.0             -1          0             0                     303.078941
#                                            1                     229.195214
# 17.0             -1          0             0                     206.034415
#                                            1                     171.720829
#
#                                                                 \
#                                                            std
# airports__sig_ct scenario_id case_study_id n_iter
# 15.0             -1          0             0       1718.757839
#                                            1       1504.757431
# 17.0             -1          0             0       1424.748360
#                                            1       1305.050083
#
#                                                   pax_p2p_modified_itinerary  \
#                                                                         mean
# airports__sig_ct scenario_id case_study_id n_iter
# 15.0             -1          0             0                        0.030452
#                                            1                        0.023161
# 17.0             -1          0             0                        0.020716
#                                            1                        0.017319
#
#
#                                                         std
# airports__sig_ct scenario_id case_study_id n_iter
# 15.0             -1          0             0       0.171828
#                                            1       0.150416
# 17.0             -1          0             0       0.142431
#                                            1       0.130459
#
# [4 rows x 106 columns]

# %% [markdown]
# # Use parametriser

# %%
# Choose scenario to be simulated
scenarios = [-1]

# Use a parametriser to be able to sweep ad-hoc parameters

parametriser_name = 'ParametriserStandard' # this is the default parametriser
parametriser = ParametriserSelector().select(parametriser_name)()

# Note that you can pass directly the name of the parametriser, if it is registred, in the Mercury object below.

## Choose some values to be simulated, only defined by the parametriser
paras_sc_iterated = {'compensation_magnitude_short':[50, 75, 100],
                       }

# You can visualise all parameters defined by the parametriser like this
parametriser.parameters
# Out:
# ['regulation_percentile',
#  'alpha_tat_mean',
#  'alpha_mct',
#  'delta_mct',
#  'alpha_non_ATFM',
#  'anchor',
#  'smoothness',
#  'claim_rate',
#  'first_compensation_threshold',
#  'second_compensation_threshold',
#  'alpha_doc_magnitude',
#  'alpha_compensation_magnitude',
#  'dci_min_threshold',
#  'dci_max_threshold',
#  'regulation_percentile_min',
#  'regulation_percentile_max',
#  'alpha_compensation_magnitude_short',
#  'alpha_compensation_magnitude_medium',
#  'alpha_compensation_magnitude_long1',
#  'alpha_compensation_magnitude_long2',
#  'compensation_magnitude_short',
#  'compensation_magnitude_medium',
#  'compensation_magnitude_long1',
#  'compensation_magnitude_long2',
#  'cruise_uncertainty_sigma',
#  'eaman_planning_horizon']

# %%
# Initialise simulation
mercury = Mercury()

# Run and get results
with clock_time():
    results, results_seq = mercury.run(scenarios=scenarios,
                                        paras_sc_iterated=paras_sc_iterated,
                                        parametriser=parametriser)
# Out:
# Simulating scenario: -1
# Simulating case study: 0
# compensation_magnitude_short = 50
# Building world...
# Starting loading data at 2023-11-28 01:29:18.547150
# Memory of process: 2394 MB
# Getting BADA performances... executed in 0:00:00.640306
# Getting schedules... executed in 0:00:00.012894
# Getting ATFM probabilities... executed in 0:00:00.009122
# Getting days regulations at airports... executed in 0:00:00.001330
# Getting flight plan pool... executed in 0:00:00.659838
# Creating flight plans... executed in 0:00:21.177188
# Getting/Creating flight plans... executed in 0:00:21.837361
# Getting curfews... executed in 0:00:00.015769
# Getting airports data... executed in 0:00:00.019716
# Getting EAMAN data... executed in 0:00:00.002401
# Getting cost data... executed in 0:00:00.050282
# Getting airline data... executed in 0:00:00.005187
# Getting flight uncertainty data... executed in 0:00:00.010238
# Getting soft cost data... executed in 0:00:00.005035
# Getting pax data... executed in 0:00:00.039380
# Getting ATFM data... executed in 0:00:00.016159
# Number of flights that can propagate to curfew: 0
# Computing flights can propagate curfew... executed in 0:00:00.010841
# Memory of process: 2441 MB
# Modules to be loaded: []
# Building agents...
# Running simulation...
# compensation_magnitude_short = 75
# Building world...
# Starting loading data at 2023-11-28 01:33:49.559782
# Memory of process: 2441 MB
# Getting BADA performances... executed in 0:00:00.565607
# Getting schedules... executed in 0:00:00.011923
# Getting ATFM probabilities... executed in 0:00:00.009179
# Getting days regulations at airports... executed in 0:00:00.001259
# Getting flight plan pool... executed in 0:00:00.408212
# Creating flight plans... executed in 0:00:10.765257
# Getting/Creating flight plans... executed in 0:00:11.173762
# Getting curfews... executed in 0:00:00.012276
# Getting airports data... executed in 0:00:00.016943
# Getting EAMAN data... executed in 0:00:00.001878
# Getting cost data... executed in 0:00:00.037034
# Getting airline data... executed in 0:00:00.002849
# Getting flight uncertainty data... executed in 0:00:00.006079
# Getting soft cost data... executed in 0:00:00.002795
# Getting pax data... executed in 0:00:00.028258
# Getting ATFM data... executed in 0:00:00.010939
# Number of flights that can propagate to curfew: 0
# Computing flights can propagate curfew... executed in 0:00:00.008629
# Memory of process: 2447 MB
# Modules to be loaded: []
# Building agents...
# Running simulation...
# compensation_magnitude_short = 100
# Building world...
# Starting loading data at 2023-11-28 01:37:45.128462
# Memory of process: 2442 MB
# Getting BADA performances... executed in 0:00:00.567838
# Getting schedules... executed in 0:00:00.011532
# Getting ATFM probabilities... executed in 0:00:00.008859
# Getting days regulations at airports... executed in 0:00:00.001274
# Getting flight plan pool... executed in 0:00:00.420531
# Creating flight plans... executed in 0:00:09.686760
# Getting/Creating flight plans... executed in 0:00:10.107580
# Getting curfews... executed in 0:00:00.012994
# Getting airports data... executed in 0:00:00.016102
# Getting EAMAN data... executed in 0:00:00.001872
# Getting cost data... executed in 0:00:00.037448
# Getting airline data... executed in 0:00:00.002834
# Getting flight uncertainty data... executed in 0:00:00.006174
# Getting soft cost data... executed in 0:00:00.002723
# Getting pax data... executed in 0:00:00.027823
# Getting ATFM data... executed in 0:00:00.010307
# Number of flights that can propagate to curfew: 0
# Computing flights can propagate curfew... executed in 0:00:00.009271
# Memory of process: 2485 MB
# Modules to be loaded: []
# Building agents...
# Running simulation...
# executed in 0:11:38.954703

# %%
results
# Out:
#                                                               arrival_delay_min  \
#                                                                            mean
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0              -0.873493
# 75                           -1          0             0               0.492729
# 100                          -1          0             0              -0.410595
#
#                                                                           \
#                                                                      std
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0       25.610497
# 75                           -1          0             0       26.218870
# 100                          -1          0             0       26.976734
#
#                                                                fuel_cost_m3  \
#                                                                        mean
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0       19535.236629
# 75                           -1          0             0       19427.465713
# 100                          -1          0             0       19575.980933
#
#                                                                              \
#                                                                         std
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0       15481.707077
# 75                           -1          0             0       15470.031933
# 100                          -1          0             0       15501.969660
#
#                                                               departure_delay_min  \
#                                                                              mean
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0                12.754147
# 75                           -1          0             0                13.424216
# 100                          -1          0             0                13.345179
#
#                                                                           \
#                                                                      std
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0       12.845670
# 75                           -1          0             0       14.084281
# 100                          -1          0             0       14.374962
#
#                                                               cancelled  \
#                                                                    mean
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0       0.021978
# 75                           -1          0             0       0.018981
# 100                          -1          0             0       0.025974
#
#                                                                          \
#                                                                     std
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0       0.146685
# 75                           -1          0             0       0.136526
# 100                          -1          0             0       0.159137
#
#                                                                  total_cost  \
#                                                                        mean
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0       21795.910519
# 75                           -1          0             0       21743.773736
# 100                          -1          0             0       21743.128002
#
#                                                                              \
#                                                                         std
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0       16314.006907
# 75                           -1          0             0       16317.566764
# 100                          -1          0             0       16348.163003
#
#                                                                ...  \
#                                                                ...
# compensation_magnitude_short scenario_id case_study_id n_iter  ...
# 50                           -1          0             0       ...
# 75                           -1          0             0       ...
# 100                          -1          0             0       ...
#
#                                                               reg_eaman_diff_tact_planned_delay_assigned  \
#                                                                                                     mean
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0                                             0.0
# 75                           -1          0             0                                             0.0
# 100                          -1          0             0                                             0.0
#
#                                                                    \
#                                                               std
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0      NaN
# 75                           -1          0             0      NaN
# 100                          -1          0             0      NaN
#
#                                                               pax_tot_arrival_delay  \
#                                                                                mean
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0                 211.533904
# 75                           -1          0             0                 185.425095
# 100                          -1          0             0                 203.376085
#
#                                                                             \
#                                                                        std
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0       1448.236109
# 75                           -1          0             0       1354.258414
# 100                          -1          0             0       1418.270278
#
#                                                               pax_modified_itinerary  \
#                                                                                 mean
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0                    0.021415
# 75                           -1          0             0                    0.018677
# 100                          -1          0             0                    0.020521
#
#                                                                          \
#                                                                     std
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0       0.144762
# 75                           -1          0             0       0.135381
# 100                          -1          0             0       0.141774
#
#                                                               pax_p2p_tot_arrival_delay  \
#                                                                                    mean
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0                     211.533904
# 75                           -1          0             0                     185.425095
# 100                          -1          0             0                     203.376085
#
#                                                                             \
#                                                                        std
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0       1448.236109
# 75                           -1          0             0       1354.258414
# 100                          -1          0             0       1418.270278
#
#                                                               pax_p2p_modified_itinerary  \
#                                                                                     mean
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0                        0.021415
# 75                           -1          0             0                        0.018677
# 100                          -1          0             0                        0.020521
#
#
#                                                                     std
# compensation_magnitude_short scenario_id case_study_id n_iter
# 50                           -1          0             0       0.144762
# 75                           -1          0             0       0.135381
# 100                          -1          0             0       0.141774
#
# [3 rows x 106 columns]

# %% [markdown]
# # Using modules' parameters

# %%
scenarios = [-1]

## Modules can define new parameters, that can be fixed or iterated upon with the same interface

paras_sc_fixed = {
                'modules__modules_to_load':['nostromo_EAMAN'], # use a module
                'nostromo_EAMAN__command_horizon': 450 # this is a parameter that exists only in this module.
                                                        # The name of the module needs to appear before the
                                                        # parameter itself
                }

paras_sc_iterated = {'nostromo_EAMAN__data_horizon':[800, 1000], # this parameter too exists only in this module
                       }
    
# All values that you do not specify in either of the dictionary will be set to their default value, defined in the scenario
# the config file of the module.

# %%
# Initialise simulation
mercury = Mercury()

# Run and get results
with clock_time():
    results, results_seq = mercury.run(scenarios=scenarios,
                                       paras_sc_fixed=paras_sc_fixed,
                                        paras_sc_iterated=paras_sc_iterated)
# Out:
# Simulating scenario: -1
# Simulating case study: 0
# nostromo_EAMAN__data_horizon = 800
# Building world...
# Starting loading data at 2023-11-28 01:40:57.542503
# Memory of process: 2428 MB
# Getting BADA performances... executed in 0:00:01.001254
# Getting schedules... executed in 0:00:00.018135
# Getting ATFM probabilities... executed in 0:00:00.026546
# Getting days regulations at airports... executed in 0:00:00.004033
# Getting flight plan pool... executed in 0:00:00.472641
# Creating flight plans... executed in 0:00:09.581065
# Getting/Creating flight plans... executed in 0:00:10.054080
# Getting curfews... executed in 0:00:00.012427
# Getting airports data... executed in 0:00:00.017139
# Getting EAMAN data... executed in 0:00:00.001830
# Getting cost data... executed in 0:00:00.037120
# Getting airline data... executed in 0:00:00.002920
# Getting flight uncertainty data... executed in 0:00:00.006292
# Getting soft cost data... executed in 0:00:00.002762
# Getting pax data... executed in 0:00:00.029696
# Getting ATFM data... executed in 0:00:00.010842
# Number of flights that can propagate to curfew: 0
# Computing flights can propagate curfew... executed in 0:00:00.008482
# Memory of process: 2487 MB
# Modules to be loaded: ['nostromo_EAMAN']
# Building agents...
# Running simulation...
# nostromo_EAMAN__data_horizon = 1000
# Building world...
# Starting loading data at 2023-11-28 01:43:07.473969
# Memory of process: 2881 MB
# Getting BADA performances... executed in 0:00:00.576189
# Getting schedules... executed in 0:00:00.012203
# Getting ATFM probabilities... executed in 0:00:00.008536
# Getting days regulations at airports... executed in 0:00:00.001400
# Getting flight plan pool... executed in 0:00:00.442227
# Creating flight plans... executed in 0:00:09.696946
# Getting/Creating flight plans... executed in 0:00:10.139451
# Getting curfews... executed in 0:00:00.013386
# Getting airports data... executed in 0:00:00.017417
# Getting EAMAN data... executed in 0:00:00.001928
# Getting cost data... executed in 0:00:00.037643
# Getting airline data... executed in 0:00:00.002996
# Getting flight uncertainty data... executed in 0:00:00.006241
# Getting soft cost data... executed in 0:00:00.002734
# Getting pax data... executed in 0:00:00.026677
# Getting ATFM data... executed in 0:00:00.013539
# Number of flights that can propagate to curfew: 0
# Computing flights can propagate curfew... executed in 0:00:00.008944
# Memory of process: 3180 MB
# Modules to be loaded: ['nostromo_EAMAN']
# Building agents...
# Running simulation...
# executed in 0:04:12.354851

# %% [markdown]
# # Use custom aggregator

# %%
# Aggregators allow use to define the dataframe you get output. By default the results are aggregated based 
# iterated parameters

# Choose scenario to be simulated
scenarios = [-1]

# Use an aggregator

## Choose some values to be simulated, only defined by the parametriser
paras_sc_iterated = {'airlines__fuel_price':[0.7, 1.5],
                       }

aggregator_name = 'ResultsAggregatorSimpleReduced' # this is the default aggregator
aggregator = ResultsAggregatorSelector().select(aggregator_name)(list(paras_sc_iterated.keys()))

# %%
# Initialise simulation
mercury = Mercury()

# Run and get results
with clock_time():
    results, results_seq = mercury.run(scenarios=scenarios,
                                        paras_sc_iterated=paras_sc_iterated,
                                        results_aggregator=aggregator)
# Out:
# Simulating scenario: -1
# Simulating case study: 0
# airlines__fuel_price = 0.7
# Building world...
# Starting loading data at 2023-11-28 01:45:09.905133
# Memory of process: 3341 MB
# Getting BADA performances... executed in 0:00:00.604416
# Getting schedules... executed in 0:00:00.012282
# Getting ATFM probabilities... executed in 0:00:00.008645
# Getting days regulations at airports... executed in 0:00:00.001250
# Getting flight plan pool... executed in 0:00:00.484336
# Creating flight plans... executed in 0:00:09.676319
# Getting/Creating flight plans... executed in 0:00:10.160965
# Getting curfews... executed in 0:00:00.013350
# Getting airports data... executed in 0:00:00.016834
# Getting EAMAN data... executed in 0:00:00.001887
# Getting cost data... executed in 0:00:00.037516
# Getting airline data... executed in 0:00:00.003093
# Getting flight uncertainty data... executed in 0:00:00.006124
# Getting soft cost data... executed in 0:00:00.002830
# Getting pax data... executed in 0:00:00.027315
# Getting ATFM data... executed in 0:00:00.010787
# Number of flights that can propagate to curfew: 0
# Computing flights can propagate curfew... executed in 0:00:00.008414
# Memory of process: 3311 MB
# Modules to be loaded: []
# Building agents...
# Running simulation...
# airlines__fuel_price = 1.5
# Building world...
# Starting loading data at 2023-11-28 01:47:12.632740
# Memory of process: 3175 MB
# Getting BADA performances... executed in 0:00:00.560739
# Getting schedules... executed in 0:00:00.011119
# Getting ATFM probabilities... executed in 0:00:00.008949
# Getting days regulations at airports... executed in 0:00:00.001370
# Getting flight plan pool... executed in 0:00:00.397688
# Creating flight plans... executed in 0:00:09.707107
# Getting/Creating flight plans... executed in 0:00:10.105078
# Getting curfews... executed in 0:00:00.016649
# Getting airports data... executed in 0:00:00.017032
# Getting EAMAN data... executed in 0:00:00.001800
# Getting cost data... executed in 0:00:00.036858
# Getting airline data... executed in 0:00:00.003458
# Getting flight uncertainty data... executed in 0:00:00.006359
# Getting soft cost data... executed in 0:00:00.002970
# Getting pax data... executed in 0:00:00.027823
# Getting ATFM data... executed in 0:00:00.009776
# Number of flights that can propagate to curfew: 0
# Computing flights can propagate curfew... executed in 0:00:00.008456
# Memory of process: 3253 MB
# Modules to be loaded: []
# Building agents...
# Running simulation...
# executed in 0:05:15.965018

# %%
results
# Out:
#                                                       arrival_delay_min  \
#                                                                    mean
# airlines__fuel_price scenario_id case_study_id n_iter
# 0.7                  -1          0             0              -0.469909
# 1.5                  -1          0             0              -0.045900
#
#                                                                   \
#                                                              std
# airlines__fuel_price scenario_id case_study_id n_iter
# 0.7                  -1          0             0       25.642740
# 1.5                  -1          0             0       26.377908
#
#                                                        fuel_cost_m3  \
#                                                                mean
# airlines__fuel_price scenario_id case_study_id n_iter
# 0.7                  -1          0             0       27202.429004
# 1.5                  -1          0             0       58208.597854
#
#                                                                      \
#                                                                 std
# airlines__fuel_price scenario_id case_study_id n_iter
# 0.7                  -1          0             0       21676.450203
# 1.5                  -1          0             0       46219.105521
#
#                                                       departure_delay_min  \
#                                                                      mean
# airlines__fuel_price scenario_id case_study_id n_iter
# 0.7                  -1          0             0                13.424238
# 1.5                  -1          0             0                13.444395
#
#                                                                  cancelled  \
#                                                              std      mean
# airlines__fuel_price scenario_id case_study_id n_iter
# 0.7                  -1          0             0       12.919617  0.016983
# 1.5                  -1          0             0       12.602281  0.017982
#
#                                                                    total_cost  \
#                                                             std          mean
# airlines__fuel_price scenario_id case_study_id n_iter
# 0.7                  -1          0             0       0.129272  29384.363327
# 1.5                  -1          0             0       0.132952  59889.071239
#
#                                                                      ...  \
#                                                                 std  ...
# airlines__fuel_price scenario_id case_study_id n_iter                ...
# 0.7                  -1          0             0       22537.369355  ...
# 1.5                  -1          0             0       47203.176627  ...
#
#                                                       reg_eaman_diff_tact_planned_delay_assigned  \
#                                                                                             mean
# airlines__fuel_price scenario_id case_study_id n_iter
# 0.7                  -1          0             0                                             0.0
# 1.5                  -1          0             0                                             0.0
#
#                                                            \
#                                                       std
# airlines__fuel_price scenario_id case_study_id n_iter
# 0.7                  -1          0             0      NaN
# 1.5                  -1          0             0      NaN
#
#                                                       pax_tot_arrival_delay  \
#                                                                        mean
# airlines__fuel_price scenario_id case_study_id n_iter
# 0.7                  -1          0             0                 147.944656
# 1.5                  -1          0             0                 182.704829
#
#                                                                     \
#                                                                std
# airlines__fuel_price scenario_id case_study_id n_iter
# 0.7                  -1          0             0       1217.467853
# 1.5                  -1          0             0       1343.165045
#
#                                                       pax_modified_itinerary  \
#                                                                         mean
# airlines__fuel_price scenario_id case_study_id n_iter
# 0.7                  -1          0             0                    0.015034
# 1.5                  -1          0             0                    0.018368
#
#                                                                  \
#                                                             std
# airlines__fuel_price scenario_id case_study_id n_iter
# 0.7                  -1          0             0       0.121689
# 1.5                  -1          0             0       0.134277
#
#                                                       pax_p2p_tot_arrival_delay  \
#                                                                            mean
# airlines__fuel_price scenario_id case_study_id n_iter
# 0.7                  -1          0             0                     147.944656
# 1.5                  -1          0             0                     182.704829
#
#                                                                     \
#                                                                std
# airlines__fuel_price scenario_id case_study_id n_iter
# 0.7                  -1          0             0       1217.467853
# 1.5                  -1          0             0       1343.165045
#
#                                                       pax_p2p_modified_itinerary  \
#                                                                             mean
# airlines__fuel_price scenario_id case_study_id n_iter
# 0.7                  -1          0             0                        0.015034
# 1.5                  -1          0             0                        0.018368
#
#
#                                                             std
# airlines__fuel_price scenario_id case_study_id n_iter
# 0.7                  -1          0             0       0.121689
# 1.5                  -1          0             0       0.134277
#
# [2 rows x 106 columns]
